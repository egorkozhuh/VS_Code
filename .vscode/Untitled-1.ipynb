# %%
# Parsing parking meters data from gis.arlingtonva.us API
import requests
import geopandas as gp
import pandas as pd
import json


url = 'https://arlgis.arlingtonva.us/arcgis/rest/services/Open_Data/od_Parking_Meter_Points/FeatureServer/0/query'

params = {
    'where': '1=1',
    'outFields': '*',
    'returnGeometry': 'true',
    'f': 'geojson'
}

response = requests.get(url, params)
assert response.status_code==200
data = response.json()

gdf = gp.GeoDataFrame.from_features(data)

#gdfNew = gdf.drop('ID', axis=1)

gdf
# Out:
#                         geometry  OBJECTID    ID               Status
# 0     POINT (-77.05378 38.86294)    306434   111  Permanently Removed  \
# 1     POINT (-77.10761 38.88174)    306435  2852  Permanently Removed
# 2     POINT (-77.08657 38.84141)    306436  2761  Permanently Removed
# 3     POINT (-77.09175 38.88955)    306437  1622               Active
# 4     POINT (-77.05551 38.85612)    306438  1745               Active
# ...                          ...       ...   ...                  ...
# 1995  POINT (-77.11206 38.87974)    308429   213  Permanently Removed
# 1996  POINT (-77.05984 38.85950)    308430  2043  Permanently Removed
# 1997  POINT (-77.07442 38.89628)    308431  2238  Permanently Removed
# 1998  POINT (-77.09296 38.88718)    308432  1818               Active
# 1999  POINT (-77.08276 38.89100)    308433   328  Permanently Removed
#
#        MeterID   DualID      Jurisdiction Block         Street
# 0      120404S     None  Arlington County   300      12th ST S  \
# 1       QU909N   QU911N  Arlington County   900    N QUINCY ST
# 2      QU2707S  QU2709S  Arlington County  2700    S QUINCY ST
# 3      ED1405N  ED1403N  Arlington County  1400  N EDGEWOOD ST
# 4     FE01901S     None  Arlington County  1900      S FERN ST
# ...        ...      ...               ...   ...            ...
# 1995      139N     None  Arlington County  4200    WILSON BLVD
# 1996   HA1526S     None  Arlington County  1500     S HAYES ST
# 1997   KB1500N  KB1502N  Arlington County  1500       KEY BLVD
# 1998  FI01201N     None  Arlington County  1100  N FILLMORE ST
# 1999   152011N  152009N  Arlington County  2000      15th ST N
#
#                  XStreetA  ... TotalCost      EntryDate cgLastModified
# 0            ARMY NAVY DR  ...      0.00  1557420146000  1680141869000  \
# 1              FAIRFAX DR  ...      0.00  1557420216000  1680141869000
# 2     S ARLINGTON MILL DR  ...      0.00  1557420214000  1680141869000
# 3             WILSON BLVD  ...      0.00  1557420185000  1680645333000
# 4               19th ST S  ...      4.25  1557420188000  1680142272000
# ...                   ...  ...       ...            ...            ...
# 1995          WILSON BLVD  ...      0.00  1557420149000  1680210224000
# 1996            18th ST S  ...      0.00  1557420196000  1680141876000
# 1997             N OAK ST  ...      0.00  1557420202000  1680141876000
# 1998       CLARENDON BLVD  ...      1.00  1557420190000  1680646300000
# 1999      N COURTHOUSE RD  ...      0.00  1557420152000  1680233676000
#
#         GeoSyncDate  Cellzone   Latitude  Longitude  cgGeoSyncDate
# 0     1682233844000     54355  38.862936 -77.053776           None  \
# 1     1682233844000     54177  38.881737 -77.107606           None
# 2     1682233844000      2201  38.841406 -77.086570           None
# 3     1682233844000     54275  38.889539 -77.091752           None
# 4     1682233844000     54057  38.856108 -77.055504           None
# ...             ...       ...        ...        ...            ...
# 1995  1682233844000     54119  38.879735 -77.112062           None
# 1996  1682233844000     54362  38.859488 -77.059836           None
# 1997  1682233844000     54518  38.896272 -77.074418           None
# 1998  1682233844000     54267  38.887175 -77.092958           None
# 1999  1682233844000     54464  38.890991 -77.082757           None
#
#      BlockFaceID PerformanceParking
# 0           None                 No
# 1           None                 No
# 2           None                 No
# 3       NEDWIFRE                Yes
# 4           None                Yes
# ...          ...                ...
# 1995        BALL                 No
# 1996        None                 No
# 1997        None                 No
# 1998    NFICL12E                Yes
# 1999    N15COTAN                 No
#
# [2000 rows x 48 columns]
